# %%
import pandas as pd

# %%
data = pd.read_csv("Worldwide Vaccine Data.csv")

# %%
data
# Out:
#               Country  Doses administered per 100 people  \
# 0         Afghanistan                                 15
# 1             Albania                                 95
# 2             Algeria                                 32
# 3              Angola                                 52
# 4           Argentina                                209
# ..                ...                                ...
# 182           Vietnam                                205
# 183  West Bank & Gaza                                 77
# 184             Yemen                                  2
# 185            Zambia                                 17
# 186          Zimbabwe                                 54
#
#      Total doses administered  % of population fully vaccinated  \
# 0                     5597130                              13.0
# 1                     2708574                              45.0
# 2                    13631683                              17.0
# ...

# %%
import requests
url ='https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=XRP&market=USD&interval=5min&apikey=ZKQGG602V9KOFOUT'
r= requests.get(url)
df=r.json()
print(df)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices and Volumes for Digital Currency', '2. Digital Currency Code': 'XRP', '3. Digital Currency Name': 'Ripple', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2022-03-23 00:00:00', '7. Time Zone': 'UTC'}, 'Time Series (Digital Currency Daily)': {'2022-03-23': {'1a. open (USD)': '0.83660000', '1b. open (USD)': '0.83660000', '2a. high (USD)': '0.84600000', '2b. high (USD)': '0.84600000', '3a. low (USD)': '0.83620000', '3b. low (USD)': '0.83620000', '4a. close (USD)': '0.83860000', '4b. close (USD)': '0.83860000', '5. volume': '8763086.00000000', '6. market cap (USD)': '8763086.00000000'}, '2022-03-22': {'1a. open (USD)': '0.83720000', '1b. open (USD)': '0.83720000', '2a. high (USD)': '0.86530000', '2b. high (USD)': '0.86530000', '3a. low (USD)': '0.82730000', '3b. low (USD)': '0.82730000', '4a. close (USD)': '0.83660000', '4b. close (USD)': '0.83660000', '5. volume': '305184306.00000000', '6. market ca
# ...

# %%
for key, value in df.items():
    print(key + ':', value)
# Out:
# Meta Data: {'1. Information': 'Daily Prices and Volumes for Digital Currency', '2. Digital Currency Code': 'XRP', '3. Digital Currency Name': 'Ripple', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2022-03-14 00:00:00', '7. Time Zone': 'UTC'}
# ...

# %%
dataframe = pd.DataFrame(df.items(),columns=["Meta Data","Time Series (Digital Currency Daily)"])

# %%
print(dataframe)
# Out:
#                               Meta Data  \
# 0                             Meta Data
# 1  Time Series (Digital Currency Daily)
#
#                 Time Series (Digital Currency Daily)
# 0  {'1. Information': 'Daily Prices and Volumes f...
# 1  {'2022-03-14': {'1a. open (USD)': '0.76020000'...

# %%
df.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Digital Currency Daily)'])

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            187 non-null    object
#  1   Doses administered per 100 people  187 non-null    int64
#  2   Total doses administered           187 non-null    int64
#  3   % of population fully vaccinated   187 non-null    float64
#  4   % of population vaccinated         187 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 7.4+ KB

# %%
data.shape
# Out:
# (187, 5)

# %%
data.describe()
# Out:
#        Doses administered per 100 people  Total doses administered  \
# count                         187.000000              1.870000e+02
# mean                          117.096257              5.817066e+07
# std                            73.554466              2.709493e+08
# min                             0.000000              1.150200e+04
# 25%                            50.500000              1.270956e+06
# 50%                           122.000000              7.033744e+06
# 75%                           179.500000              2.464262e+07
# max                           309.000000              3.160685e+09
#
#        % of population fully vaccinated  % of population vaccinated
# count                        187.000000                  187.000000
# mean                          53.431551                   47.727807
# std                           27.349733                   26.761376
# min                            0.100000                    0.100000
# ...

# %%
data.sort_values("% of population fully vaccinated")
# Out:
#       Country  Doses administered per 100 people  Total doses administered  \
# 26    Burundi                                  0                     11502
# 36      Congo                                  1                    850731
# 68      Haiti                                  2                    239355
# 32       Chad                                  2                    403992
# 184     Yemen                                  2                    784792
# ..        ...                                ...                       ...
# 33      Chile                                259                  49060956
# 133  Portugal                                223                  22894578
# 105     Malta                                248                   1245686
# 23     Brunei                                240                   1041610
# 173    U.A.E.                                248                  24222001
#
#      % of population fully vaccinated  % of population vaccinated
# ...

# %%
data.sort_values(["% of population fully vaccinated","Doses administered per 100 people"])
# Out:
#      Country  Doses administered per 100 people  Total doses administered  \
# 26   Burundi                                  0                     11502
# 36     Congo                                  1                    850731
# 68     Haiti                                  2                    239355
# 32      Chad                                  2                    403992
# 184    Yemen                                  2                    784792
# ..       ...                                ...                       ...
# 23    Brunei                                240                   1041610
# 105    Malta                                248                   1245686
# 33     Chile                                259                  49060956
# 39      Cuba                                309                  35063358
# 173   U.A.E.                                248                  24222001
#
#      % of population fully vaccinated  % of population vaccinated
# ...

# %%
data.sort_values(["% of population fully vaccinated","Doses administered per 100 people"], ascending=[False,True])
# Out:
#       Country  Doses administered per 100 people  Total doses administered  \
# 173    U.A.E.                                248                  24222001
# 133  Portugal                                223                  22894578
# 23     Brunei                                240                   1041610
# 105     Malta                                248                   1245686
# 33      Chile                                259                  49060956
# ..        ...                                ...                       ...
# 184     Yemen                                  2                    784792
# 32       Chad                                  2                    403992
# 68      Haiti                                  2                    239355
# 36      Congo                                  1                    850731
# 26    Burundi                                  0                     11502
#
#      % of population fully vaccinated  % of population vaccinated
# ...

# %%
data[data["Country"]=="Ireland"]
# Out:
#     Country  Doses administered per 100 people  Total doses administered  \
# 77  Ireland                                215                  10620191
#
#     % of population fully vaccinated  % of population vaccinated
# 77                              82.0                        80.0

# %%
data[["Country","Doses administered per 100 people","% of population fully vaccinated"]]
# Out:
#               Country  Doses administered per 100 people  \
# 0         Afghanistan                                 15
# 1             Albania                                 95
# 2             Algeria                                 32
# 3              Angola                                 52
# 4           Argentina                                209
# ..                ...                                ...
# 182           Vietnam                                205
# 183  West Bank & Gaza                                 77
# 184             Yemen                                  2
# 185            Zambia                                 17
# 186          Zimbabwe                                 54
#
#      % of population fully vaccinated
# 0                                13.0
# 1                                45.0
# 2                                17.0
# 3                                34.0
# 4                                90.0
# ..                                ...
# ...

# %%
data.drop_duplicates(subset="Country")
# Out:
#               Country  Doses administered per 100 people  \
# 0         Afghanistan                                 15
# 1             Albania                                 95
# 2             Algeria                                 32
# 3              Angola                                 52
# 4           Argentina                                209
# ..                ...                                ...
# 182           Vietnam                                205
# 183  West Bank & Gaza                                 77
# 184             Yemen                                  2
# 185            Zambia                                 17
# 186          Zimbabwe                                 54
#
#      Total doses administered  % of population fully vaccinated  \
# 0                     5597130                              13.0
# 1                     2708574                              45.0
# 2                    13631683                              17.0
# ...

# %%
data["% of population fully vaccinated"].value_counts()
# Out:
# 87.0    6
# 76.0    6
# 94.0    5
# 65.0    5
# 85.0    5
#        ..
# 36.0    1
# 40.0    1
# 3.9     1
# 91.0    1
# 30.0    1
# Name: % of population fully vaccinated, Length: 88, dtype: int64

# %%
data_ind = data.set_index("Country")
print(data_ind)
# Out:
#                   Doses administered per 100 people  Total doses administered  \
# Country
# Afghanistan                                      15                   5597130
# Albania                                          95                   2708574
# Algeria                                          32                  13631683
# Angola                                           52                  16633167
# Argentina                                       209                  94081179
# ...                                             ...                       ...
# Vietnam                                         205                 197571534
# West Bank & Gaza                                 77                   3609984
# Yemen                                             2                    784792
# Zambia                                           17                   3027612
# Zimbabwe                                         54                   7936145
#
# ...

# %%
data_ind.loc[["Ireland","Italy","France","Spain"]]
# Out:
#          Doses administered per 100 people  Total doses administered  \
# Country
# Ireland                                215                  10620191
# Italy                                  223                 134593644
# France                                 210                 140971367
# Spain                                  197                  92774397
#
#          % of population fully vaccinated  % of population vaccinated
# Country
# Ireland                              82.0                        80.0
# Italy                                84.0                        79.0
# France                               80.0                        78.0
# Spain                                87.0                        83.0

# %%
data.index
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %%
data_ind2=data.set_index("Doses administered per 100 people").sort_index(ascending=False)
print(data_ind2)
# Out:
#                                    Country  Total doses administered  \
# Doses administered per 100 people
# 309                                   Cuba                  35063358
# 259                                  Chile                  49060956
# 248                                 U.A.E.                  24222001
# 248                                  Malta                   1245686
# 240                                 Brunei                   1041610
# ...                                    ...                       ...
# 2                                    Yemen                    784792
# 2                                    Haiti                    239355
# 2                                     Chad                    403992
# 1                                    Congo                    850731
# 0                                  Burundi                     11502
#
#                                    % of population fully vaccinated  \
# ...

# %%
data_ind2.loc[309:200]
# Out:
#                                           Country  Total doses administered  \
# Doses administered per 100 people
# 309                                          Cuba                  35063358
# 259                                         Chile                  49060956
# 248                                        U.A.E.                  24222001
# 248                                         Malta                   1245686
# 240                                        Brunei                   1041610
# 238                                     Singapore                  13572663
# 231                                   South Korea                 119554477
# 226                                Mainland China                3160685000
# 226                                         Qatar                   6398889
# 226                                       Denmark                  13172046
# 223                                      Portugal                  22894578
# ...

# %%
data_ind2.loc[309:200,"Country":"% of population fully vaccinated"]
# Out:
#                                           Country  Total doses administered  \
# Doses administered per 100 people
# 309                                          Cuba                  35063358
# 259                                         Chile                  49060956
# 248                                        U.A.E.                  24222001
# 248                                         Malta                   1245686
# 240                                        Brunei                   1041610
# 238                                     Singapore                  13572663
# 231                                   South Korea                 119554477
# 226                                Mainland China                3160685000
# 226                                         Qatar                   6398889
# 226                                       Denmark                  13172046
# 223                                      Portugal                  22894578
# ...

# %%
data_ind2.iloc[0:34,0:3]
# Out:
#                                           Country  Total doses administered  \
# Doses administered per 100 people
# 309                                          Cuba                  35063358
# 259                                         Chile                  49060956
# 248                                        U.A.E.                  24222001
# 248                                         Malta                   1245686
# 240                                        Brunei                   1041610
# 238                                     Singapore                  13572663
# 231                                   South Korea                 119554477
# 226                                Mainland China                3160685000
# 226                                         Qatar                   6398889
# 226                                       Denmark                  13172046
# 223                                      Portugal                  22894578
# ...

# %%
europe = {"Denmark":226,"Portugal":223,"Italy":223,"Iceland":222,"Belgium":218,"France":210,"U.K.":210,"Norway":210,"Finland":208,"Luxembourg":205,"Germany":205,"Austria":203,"Sweden":201}

# %%
europe["Ireland"]=215

# %%
"Ireland" in europe
# Out:
# True

# %%
europe
# Out:
# {'Denmark': 226,
#  'Portugal': 223,
#  'Italy': 223,
#  'Iceland': 222,
#  'Belgium': 218,
#  'France': 210,
#  'U.K.': 210,
#  'Norway': 210,
#  'Finland': 208,
#  'Luxembourg': 205,
#  'Germany': 205,
#  'Austria': 203,
#  'Sweden': 201,
#  'Ireland': 215}

# %%
del(europe["U.K."])

# %%
europe
# Out:
# {'Denmark': 226,
#  'Portugal': 223,
#  'Italy': 223,
#  'Iceland': 222,
#  'Belgium': 218,
#  'France': 210,
#  'Norway': 210,
#  'Finland': 208,
#  'Luxembourg': 205,
#  'Germany': 205,
#  'Austria': 203,
#  'Sweden': 201,
#  'Ireland': 215}

# %%
XRP= pd.DataFrame(df)

# %%
XRP
# Out:
#                                                               Meta Data  \
# 1. Information            Daily Prices and Volumes for Digital Currency
# 2. Digital Currency Code                                            XRP
# 3. Digital Currency Name                                         Ripple
# 4. Market Code                                                      USD
# 5. Market Name                                     United States Dollar
# ...                                                                 ...
# 2019-06-23                                                          NaN
# 2019-06-22                                                          NaN
# 2019-06-21                                                          NaN
# 2019-06-20                                                          NaN
# 2019-06-19                                                          NaN
#
#                                        Time Series (Digital Currency Daily)
# ...

# %%
XRP[7:20]
# Out:
#            Meta Data               Time Series (Digital Currency Daily)
# 2022-03-14       NaN  {'1a. open (USD)': '0.76020000', '1b. open (US...
# 2022-03-13       NaN  {'1a. open (USD)': '0.78570000', '1b. open (US...
# 2022-03-12       NaN  {'1a. open (USD)': '0.80280000', '1b. open (US...
# 2022-03-11       NaN  {'1a. open (USD)': '0.73610000', '1b. open (US...
# 2022-03-10       NaN  {'1a. open (USD)': '0.76590000', '1b. open (US...
# 2022-03-09       NaN  {'1a. open (USD)': '0.72080000', '1b. open (US...
# 2022-03-08       NaN  {'1a. open (USD)': '0.71960000', '1b. open (US...
# 2022-03-07       NaN  {'1a. open (USD)': '0.72520000', '1b. open (US...
# 2022-03-06       NaN  {'1a. open (USD)': '0.75390000', '1b. open (US...
# 2022-03-05       NaN  {'1a. open (USD)': '0.71270000', '1b. open (US...
# 2022-03-04       NaN  {'1a. open (USD)': '0.75140000', '1b. open (US...
# 2022-03-03       NaN  {'1a. open (USD)': '0.76880000', '1b. open (US...
# ...

# %%
import numpy as np

# %%
file="country_wise_latest.csv"

# %%
np_data=np.loadtxt(file,delimiter=',',dtype=str)

# %%
np_data
# Out:
# array([['Country/Region', 'Confirmed', 'Deaths', ..., '1 week change',
#         '1 week % increase', 'WHO Region'],
#        ['Afghanistan', '36263', '1269', ..., '737', '2.07',
#         'Eastern Mediterranean'],
#        ['Albania', '4880', '144', ..., '709', '17', 'Europe'],
#        ...,
#        ['Yemen', '1691', '483', ..., '72', '4.45',
#         'Eastern Mediterranean'],
#        ['Zambia', '4552', '140', ..., '1226', '36.86', 'Africa'],
#        ['Zimbabwe', '2704', '36', ..., '991', '57.85', 'Africa']],
#       dtype='<U32')

# %%
np_data[1:10]
# Out:
# array([['Afghanistan', '36263', '1269', '25198', '9796', '106', '10',
#         '18', '3.5', '69.49', '5.04', '35526', '737', '2.07',
#         'Eastern Mediterranean'],
#        ['Albania', '4880', '144', '2745', '1991', '117', '6', '63',
#         '2.95', '56.25', '5.25', '4171', '709', '17', 'Europe'],
#        ['Algeria', '27973', '1163', '18837', '7973', '616', '8', '749',
#         '4.16', '67.34', '6.17', '23691', '4282', '18.07', 'Africa'],
#        ['Andorra', '907', '52', '803', '52', '10', '0', '0', '5.73',
#         '88.53', '6.48', '884', '23', '2.6', 'Europe'],
#        ['Angola', '950', '41', '242', '667', '18', '1', '0', '4.32',
#         '25.47', '16.94', '749', '201', '26.84', 'Africa'],
#        ['Antigua and Barbuda', '86', '3', '65', '18', '4', '0', '5',
#         '3.49', '75.58', '4.62', '76', '10', '13.16', 'Americas'],
#        ['Argentina', '167416', '3059', '72575', '91782', '4890', '120',
# ...

# %%
type(np_data)
# Out:
# numpy.ndarray

# %%
np_data.shape
# Out:
# (188, 15)

# %%
np_data[84]
# Out:
# array(['Ireland', '25892', '1764', '23364', '764', '11', '0', '0', '6.81',
#        '90.24', '7.55', '25766', '126', '0.49', 'Europe'], dtype='<U32')

# %%
np_data[84][2]
# Out:
# '1764'

# %%
data_cases=pd.read_csv("country_wise_latest.csv")

# %%
data_cases.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data_merge=data_cases.merge(data,left_on='Country/Region',right_on="Country")

# %%
data_merge.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3         Angola        950      41        242     667         18           1
# 4      Argentina     167416    3059      72575   91782       4890         120
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                4.32                  25.47
# 4           2057                1.83                  43.35
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
del(data_merge["Country"])

# %%
data_merge.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3         Angola        950      41        242     667         18           1
# 4      Argentina     167416    3059      72575   91782       4890         120
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                4.32                  25.47
# 4           2057                1.83                  43.35
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data_merge=data_cases.merge(data,how='outer',left_on='Country/Region',right_on="Country")

# %%
data_merge
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0      Afghanistan    36263.0  1269.0    25198.0  9796.0      106.0
# 1          Albania     4880.0   144.0     2745.0  1991.0      117.0
# 2          Algeria    27973.0  1163.0    18837.0  7973.0      616.0
# 3          Andorra      907.0    52.0      803.0    52.0       10.0
# 4           Angola      950.0    41.0      242.0   667.0       18.0
# ..             ...        ...     ...        ...     ...        ...
# 208            NaN        NaN     NaN        NaN     NaN        NaN
# 209            NaN        NaN     NaN        NaN     NaN        NaN
# 210            NaN        NaN     NaN        NaN     NaN        NaN
# 211            NaN        NaN     NaN        NaN     NaN        NaN
# 212            NaN        NaN     NaN        NaN     NaN        NaN
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10.0           18.0                3.50                  69.49
# ...

# %%
m=((data_merge["Country/Region"].isnull())|
   (data_merge["Country"].isnull()))

# %%
print(data_merge[m])
# Out:
#             Country/Region  Confirmed    Deaths  Recovered     Active  \
# 3                  Andorra      907.0      52.0      803.0       52.0
# 5      Antigua and Barbuda       86.0       3.0       65.0       18.0
# 27                   Burma      350.0       6.0      292.0       52.0
# 29              Cabo Verde     2328.0      22.0     1550.0      756.0
# 36                   China    86783.0    4656.0    78869.0     3258.0
# 39     Congo (Brazzaville)     3200.0      54.0      829.0     2317.0
# 40        Congo (Kinshasa)     8844.0     208.0     5700.0     2936.0
# 42           Cote d'Ivoire    15655.0      96.0    10361.0     5198.0
# 46                 Czechia    15516.0     373.0    11428.0     3715.0
# 49                Dominica       18.0       0.0       18.0        0.0
# 50      Dominican Republic    64156.0    1083.0    30204.0    32869.0
# 55                 Eritrea      265.0       0.0      191.0       74.0
# ...

# %%
anti_join=data_cases.merge(data,how='left',left_on='Country/Region',right_on='Country',indicator=True)

# %%
print(anti_join.head())
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  ...  \
# 0             18                3.50                  69.49  ...
# 1             63                2.95                  56.25  ...
# 2            749                4.16                  67.34  ...
# 3              0                5.73                  88.53  ...
# 4              0                4.32                  25.47  ...
#
#    Confirmed last week  1 week change  1 week % increase  \
# ...

# %%
anti_join_list=anti_join.loc[anti_join['_merge'] =='left_only','Country/Region']

# %%
print(anti_join_list)
# Out:
# 3                    Andorra
# 5        Antigua and Barbuda
# 27                     Burma
# 29                Cabo Verde
# 36                     China
# 39       Congo (Brazzaville)
# 40          Congo (Kinshasa)
# 42             Cote d'Ivoire
# 46                   Czechia
# 49                  Dominica
# 50        Dominican Republic
# 55                   Eritrea
# 68                 Greenland
# 75                  Holy See
# 100            Liechtenstein
# 113                   Monaco
# 140    Saint Kitts and Nevis
# 143               San Marino
# 144    Sao Tome and Principe
# 148               Seychelles
# 164                  Taiwan*
# 173                       US
# 176     United Arab Emirates
# 177           United Kingdom
# 182       West Bank and Gaza
# 183           Western Sahara
# Name: Country/Region, dtype: object

# %%
ajr=data.merge(data_cases,how='left',left_on='Country',right_on='Country/Region',indicator=True)

# %%
ajr_list=ajr.loc[ajr['_merge'] =='left_only','Country']

# %%
print(ajr_list)
# Out:
# 6                      Aruba
# 30                Cape Verde
# 36                     Congo
# 40                   Curaçao
# 42            Czech Republic
# 45            Dominican Rep.
# 56          French Polynesia
# 70                 Hong Kong
# 80               Ivory Coast
# 86                  Kiribati
# 98                     Macau
# 100           Mainland China
# 114                  Myanmar
# 118            New Caledonia
# 135    Republic of the Congo
# 141                    Samoa
# 142    São Tomé and Príncipe
# 150          Solomon Islands
# 162                   Taiwan
# 168                    Tonga
# 172             Turkmenistan
# 173                   U.A.E.
# 174                     U.K.
# 177            United States
# 180                  Vanuatu
# 183         West Bank & Gaza
# Name: Country, dtype: object

# %%
non_ajr=data[data['Country'].isin(ajr_list)]

# %%
print(non_ajr)
# Out:
#                    Country  Doses administered per 100 people  \
# 6                    Aruba                                158
# 30              Cape Verde                                129
# 36                   Congo                                  1
# 40                 Curaçao                                156
# 42          Czech Republic                                163
# 45          Dominican Rep.                                142
# 56        French Polynesia                                130
# 70               Hong Kong                                182
# 80             Ivory Coast                                 39
# 86                Kiribati                                103
# 98                   Macau                                179
# 100         Mainland China                                226
# 114                Myanmar                                 83
# 118          New Caledonia                                127
# ...

# %%
import matplotlib.pyplot as plt

# %%
data_merge = data_merge.dropna() 
#could use fillna(0) but will result in incorrect analysis
print(data_merge)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0      Afghanistan    36263.0  1269.0    25198.0   9796.0      106.0
# 1          Albania     4880.0   144.0     2745.0   1991.0      117.0
# 2          Algeria    27973.0  1163.0    18837.0   7973.0      616.0
# 4           Angola      950.0    41.0      242.0    667.0       18.0
# 6        Argentina   167416.0  3059.0    72575.0  91782.0     4890.0
# ..             ...        ...     ...        ...      ...        ...
# 180      Venezuela    15988.0   146.0     9959.0   5883.0      525.0
# 181        Vietnam      431.0     0.0      365.0     66.0       11.0
# 184          Yemen     1691.0   483.0      833.0    375.0       10.0
# 185         Zambia     4552.0   140.0     2815.0   1597.0       71.0
# 186       Zimbabwe     2704.0    36.0      542.0   2126.0      192.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data_merge.groupby('WHO Region')["Deaths"].mean()
# Out:
# WHO Region
# Africa                    295.700000
# Americas                 6454.500000
# Eastern Mediterranean    1895.800000
# Europe                   3433.916667
# South-East Asia          4593.666667
# Western Pacific           256.142857
# Name: Deaths, dtype: float64

# %%
data_merge.groupby('WHO Region')["Deaths"].agg([min,max,sum])
# Out:
#                         min      max       sum
# WHO Region
# Africa                  1.0   7067.0   11828.0
# Americas                0.0  87618.0  193635.0
# Eastern Mediterranean  11.0  15912.0   37916.0
# Europe                  9.0  35112.0  164828.0
# South-East Asia         0.0  33408.0   41343.0
# Western Pacific         0.0   1945.0    3586.0

# %%
fig, ax=plt.subplots()
ax.plot(data_merge.index,data_merge['Recovered'])
plt.show()
#Unable to use 'Country' as it is a float, need to set it as index

# %%
data_merge.set_index('Country/Region')
# Out:
#                 Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Country/Region
# Afghanistan       36263.0  1269.0    25198.0   9796.0      106.0        10.0
# Albania            4880.0   144.0     2745.0   1991.0      117.0         6.0
# Algeria           27973.0  1163.0    18837.0   7973.0      616.0         8.0
# Angola              950.0    41.0      242.0    667.0       18.0         1.0
# Argentina        167416.0  3059.0    72575.0  91782.0     4890.0       120.0
# ...                   ...     ...        ...      ...        ...         ...
# Venezuela         15988.0   146.0     9959.0   5883.0      525.0         4.0
# Vietnam             431.0     0.0      365.0     66.0       11.0         0.0
# Yemen              1691.0   483.0      833.0    375.0       10.0         4.0
# Zambia             4552.0   140.0     2815.0   1597.0       71.0         1.0
# Zimbabwe           2704.0    36.0      542.0   2126.0      192.0         2.0
#
# ...

# %%
fig, ax=plt.subplots()
ax.plot(data_merge['Country/Region'],data_merge['Deaths'])
plt.show()
#set as index but country names are unreadable as there is too many work with regions instead using a bar plot to combine all points

# %%
data_merge.set_index('WHO Region')
# Out:
#                       Country/Region  Confirmed  Deaths  Recovered   Active  \
# WHO Region
# Eastern Mediterranean    Afghanistan    36263.0  1269.0    25198.0   9796.0
# Europe                       Albania     4880.0   144.0     2745.0   1991.0
# Africa                       Algeria    27973.0  1163.0    18837.0   7973.0
# Africa                        Angola      950.0    41.0      242.0    667.0
# Americas                   Argentina   167416.0  3059.0    72575.0  91782.0
# ...                              ...        ...     ...        ...      ...
# Americas                   Venezuela    15988.0   146.0     9959.0   5883.0
# Western Pacific              Vietnam      431.0     0.0      365.0     66.0
# Eastern Mediterranean          Yemen     1691.0   483.0      833.0    375.0
# Africa                        Zambia     4552.0   140.0     2815.0   1597.0
# Africa                      Zimbabwe     2704.0    36.0      542.0   2126.0
#
# ...

# %%
fig, ax=plt.subplots()
ax.bar(data_merge['WHO Region'],data_merge['Deaths'])
plt.show()
#labels are too long some are still unreadable must roatate them

# %%
fig, ax=plt.subplots()
ax.bar(data_merge['WHO Region'],data_merge['Deaths'])
ax.set_xlabel('WHO Regions')
ax.set_xticks(data_merge['WHO Region'])
ax.set_xticklabels(data_merge['WHO Region'],rotation=90)
ax.set_ylabel('Number of Deaths')
plt.show()
#from this we can easily visualize the proportion of deaths in americas compared to the other regions

# %%
fig, ax=plt.subplots()

ax.bar(data_merge['WHO Region'],data_merge['Recovered'],label='Recovered')
ax.bar(data_merge['WHO Region'],data_merge['Active'],label='Active')
ax.set_xlabel('WHO Regions')
ax.set_xticks(data_merge['WHO Region'])
ax.set_xticklabels(data_merge['WHO Region'],rotation=90)
ax.set_ylabel('Number of Confirmed cases')
ax.legend()
plt.show()
#Want to add more data so as to show comparison  between those recovered and those R.I.P. abd those still active =total confirmed cases

# %%
WHO_column= data_merge['WHO Region']
regions=WHO_column.unique()
print(regions)
# Out:
# ['Eastern Mediterranean' 'Europe' 'Africa' 'Americas' 'Western Pacific'
#  'South-East Asia']

# %%
fig, ax=plt.subplots()
for region in regions:
    region_df = data_merge[data_merge['WHO Region']==region]
    ax.bar(region, region_df['Doses administered per 100 people'].mean(),yerr=region_df['Doses administered per 100 people'].std())
ax.set_xlabel('Regions')
ax.set_ylabel("Doses administered per 100 people")
ax.set_xticklabels(regions,rotation=45)
plt.show()
#Here we iterate over the values of regions setting region as the loop variable
#in each iteration the rows where the WHO Region column is equal to regions is extracted
#a bar is added to the provided ax object, labeled with the region names, with the mean of the "Doses administered per 100 people" column as its height, and the standard deviation as a y-axis error bar.
# Out:
# C:\Users\eoind\AppData\Local\Temp/ipykernel_10028/618829345.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(regions,rotation=45)

# %%
regions_grouped=data_merge.groupby(['WHO Region']).mean()
regions_grouped
# Out:
#                            Confirmed       Deaths      Recovered  \
# WHO Region
# Africa                  17298.150000   295.700000   10530.825000
# Americas               149491.666667  6454.500000  103750.333333
# Eastern Mediterranean   71047.300000  1895.800000   57256.900000
# Europe                  62093.020833  3433.916667   41233.083333
# South-East Asia        203883.000000  4593.666667  128515.666667
# Western Pacific         14655.928571   256.142857    9104.357143
#
#                              Active    New cases  New deaths  New recovered  \
# WHO Region
# Africa                  6471.625000   297.925000    8.650000     349.350000
# Americas               39286.833333  2398.100000   81.966667    2174.300000
# Eastern Mediterranean  11894.600000   599.700000   22.100000     725.750000
# Europe                 17426.020833   445.895833    6.145833     244.354167
# South-East Asia        70773.666667  5443.666667   81.555556    4175.555556
# ...

# %%
import seaborn as sns
sns.scatterplot(x=data_merge["Deaths / 100 Cases"],y=data_merge["Doses administered per 100 people"],data=data_merge,hue="WHO Region")
plt.show()

# %%
sns.set_context("talk")
sns.relplot(x="% of population fully vaccinated",y="New deaths",data=data_merge,kind="scatter",col="WHO Region")
plt.show()

# %%
sns.set_context("paper")
g=sns.catplot(y="WHO Region",x="% of population fully vaccinated",data=data_merge,kind="box")
g.fig.suptitle("Distribution of Population Vaccinated per Country, Grouped by Region",y=1.05)
# Out:
# Text(0.5, 1.05, 'Distribution of Population Vaccinated per Country, Grouped by Region')

# %%
sns.lmplot(x="Doses administered per 100 people",y="Recovered / 100 Cases",data=data_merge,hue="WHO Region")

# %%
sns.lmplot(x="Doses administered per 100 people",y="Recovered / 100 Cases",data=data_merge,col="WHO Region")
